# %%
import pandas as pd
from tira.rest_api_client import Client
from tira.third_party_integrations import ensure_pyterrier_is_loaded, persist_and_normalize_run, ir_datasets
from tqdm import tqdm

# This method ensures that that PyTerrier is loaded so that it also works in the TIRA sandbox
ensure_pyterrier_is_loaded()
import pyterrier as pt


tira = Client()
dataset_id = 'longeval-2023-01-20240423-training'
pt_dataset = pt.get_dataset(f'irds:ir-benchmarks/{dataset_id}')

__normalize_queries = lambda q: q.lower().strip()

def load_oracle_index(file_name='../oracle-indexing/oracle-index.jsonl.gz', allowed_dataset_ids=('longeval-train-20230513-training', 'longeval-heldout-20230513-training', 'longeval-short-july-20230513-training', 'longeval-long-september-20230513-training')):
    entries = pd.read_json(file_name, orient='records', lines=True)
    entries = [i.to_dict() for _, i in entries.iterrows() if i['relevance'] > 0]
    ret = {}

    for entry in entries:
        if entry['dataset'] not in allowed_dataset_ids:
            continue
        query = __normalize_queries(entry['query'])
        if query not in ret:
            ret[query] = []
        ret[query].append(entry)

    return ret

# %%
oracle_index = load_oracle_index()

# %%
bm25_raw = tira.pt.from_submission('ir-benchmarks/tira-ir-starter/BM25 (tira-ir-starter-pyterrier)', dataset_id) %900
# Out:
# {'status': 0, 'context': {'include_navigation': False, 'user_id': None, 'role': 'guest', 'organizer_teams': '[]', 'submission': {'docker_software_id': 244, 'display_name': 'BM25 (tira-ir-starter-pyterrier)', 'user_image_name': 'registry.webis.de/code-research/tira/tira-user-tira-ir-starter/pyterrier:0.0.1', 'command': '/workspace/pyterrier_cli.py --input $inputDataset --output $outputDir --index_directory $inputRun --params wmodel=BM25 --retrieval_pipeline default_pipelines.wmodel_batch_retrieve', 'tira_image_name': 'registry.webis.de/code-research/tira/tira-user-tira-ir-starter/pyterrier:0.0.1-tira-docker-software-id-sienna-bug', 'task_id': 'ir-benchmarks', 'vm_id': 'tira-ir-starter', 'description': '', 'paper_link': '', 'input_docker_software': 'Index (tira-ir-starter-pyterrier)', 'input_docker_software_id': 243, 'input_upload_id': None, 'ir_re_ranker': False, 'public_image_name': 'docker.io/webis/ir-benchmarks-submissions:tira-ir-starter-pyterrier-0-0-1-tira-docker-software-id-sienna-bug', 'ir_re_ranking_input': True, 'previous_stages': ['Index (tira-ir-starter-pyterrier)'], 'link_code': None, 'mount_hf_model': None}}}

# %%
index = tira.pt.index('ir-benchmarks/tira-ir-starter/Index (tira-ir-starter-pyterrier)', dataset_id)

# %%
docs = bm25_raw(pt_dataset.get_topics('text'))

# %%
overlapping_queries = {i.query_id: i.default_text() for i in pt_dataset.irds_ref().queries_iter()}
overlapping_queries = {k: v for k, v in overlapping_queries.items() if __normalize_queries(v) in oracle_index}

# %%
doc_ids = []

for _, i in bm25_raw(pt_dataset.get_topics('text')).iterrows():
    if i['qid'] in overlapping_queries:
        doc_ids.append(i['docno'])

doc_ids = set(doc_ids)

# %%
len(doc_ids)
# Out:
# 91458

# %%
docs_for_reformulation = []

for i in tqdm(pt_dataset.get_corpus_iter()):
    if i['docno'] not in doc_ids:
        continue
    docs_for_reformulation += [i]
# Out:
# ir-benchmarks/longeval-2023-01-20240423-training documents: 100%|██████████| 2049729/2049729 [02:13<00:00, 15370.74it/s]
# 100%|██████████| 2049729/2049729 [02:13<00:00, 15370.88it/s]

# %%
docs_for_reformulation[:2]
# Out:
# [{'text': '\n\nOriginal apple-themed grocery and restaurant in Paris!\nPomze France\n- Island of France\n- Paris\n- Paris\nPresentation\nDaniel and Emmanuel Dayan have made it their mission to put the humble apple back on the map.\nAnd their idea paid off, as Pomze was born in the middle of Paris!\nBoth a monomaniacal grocery store and a restaurant, their Locavore UFO promotes the artisans of this terroirist product and turns it down to envy.\nOn the Deco side, upstairs, we start in a frenzy in the orchards of France, the pictures of which decorate the walls of this former Haussmann apartment.\nOn the menu, the inventive plates of Nicolas Soliman: mackerel with cider, salad vinegar, shredded cabbage, sour apples and nuts;\nTonka bean lacquered fillet and roasted plums with pommel;\ntarte Tatin in thousand leaves of apples Reinette confites and milk ribot ice...\nNot to mention the monthly match "a big cheese, a big cider" (you know what to drink, by the way).\nServices Blue Card , Mastercard , Visa Card\nPrivatizable restaurant (max 6 persons)\nDisabled access , Air-conditioned , English spoken , Master Restaurateur , Privatisable , Wifi Good to know How to go there ?\nParking Bergson, Place Saint\nAugustin Unusual Surprises\nAdd to my favorites Cooking: French\nOpening hours:\nLunch: 12:15 p.m. to 2:30 p.m. (except Saturday and Sunday)\nDinner: from 19:00 to 21:30 (except Saturday and Sunday in July and August )\nClosed period Budget: from 21€ to 50€ See availability and rates Selected unusual accommodation in the same region No hotel suggested at this time Stay in love Paris (Île de France)\nThe VIP Paris is the only Yacht-Hotel sailing from the capital.\nOn this occasion, we propose to the...\nBudget: more than €200\nWeekend lovers stay in Paris with sensory rooms, in-room Jacuzzi, swimming pool, Hammam and much more...\nBudget: more than €200\nStay in love Paris (Île de France) Ideas for a weekend in love in Paris with SPA and sauna:\nLes Résidences Lavaud Guesthouse offers 2...\nBudget: more than €200\nNo activity suggested at this time Games and Entertainment Paris (Île de France)\nAre you looking for a track game, an original activity to do with friends or family in Paris?\nYou...\nBudget: €0 to €50 Games and entertainment Le Coudray-Montceaux (Île de France)\nThe Nolimit Aventure park, located in Le Coudray Montceaux in Essonne, offers you a multitude of...\nBudget: €0 to €50 Games and Entertainment Chevry Cossigny (Île de France)\nThe park Nolimit Aventure, located in Chevry Cossigny in île de France and only 20 min from Paris ,\n... Budget: from 0 to 50€ ×\nReceive our vouchers\nplans Travel ideas, promos, actus...\nid Registration date Email cgu * I agree to receive via e-mail the Insolitour.com newsletter and I have read the privacy policy of this website.\nI sign up Insolitour Log in to your account to add favorites Email * Password * Remember me I log in to my account\n\n\n',
#   'docno': 'doc012309100013'},
#  {'text': '\n\niPapy\n:\nSandhya\nRaga by Ravi Shankar, played by his students Saturday, May 16, 2020 .\nOn the occasion of the hundredth anniversary of his birth on April 7th... .\nPublished by Corinne on Saturday, May 16, 2020 Extraordinary and warm, it is a mixture of dexterity and benevolence.\nThank you, Corinne.\nThe Path of the Warrior .\nFour years ago cancer and its brutal arrival reminded me in pain of the obvious to ponder for every person...\nPlease give me the strength .\nA beautiful song- prayer of our friend Didier... who wants to clarify that the "disease" (disease) of which he is quest...\nArticle by the Dalai Lama\nLama\nTime\nmagazine\n14/04/20\n.\n"Sometimes friends\nask\nme\nto help with\nsome\nproblem\nin the world, using some\n“\nmagical powers.\n” I always tell them that th... Kalachakra / Nathalie Fuchs .\nKalachakrafree 25fps VFRSTFR\nMix St\nHD\nH264 170419 (1) from\nLeelame Production\non Vimeo .\nA very nice film.\nThank you H... 37 birdsong... .\nAnd if you have the chance like us to have a garden, you are every day at the concert ...! .\nViewpoint .\nHe doesn\'t know it yet, but Monday is the end of the recess.... .\nA few words in French / Ma Divya Jyoti .\nIn a few very simple words, the course of action: continue the Sadhana, stay connected to the Essential, do what...\niPapy Stats headings from the iPapy provided by Blogger .\n\n\n',
#   'docno': 'doc012309100034'}]

# %%
additional_docs = {}

for i in oracle_index:
    for j in oracle_index[i]:
        additional_docs[j['doc_id']] = j['doc']

additional_docs = [{'docno': 'ADD_' + k, 'text': v} for k, v in additional_docs.items()]

# %%
additional_docs[:2]
# Out:
# [{'docno': 'ADD_doc062200105012',
#   'text': '\n\nUpCadhoc:\nMulti-Sign Card and Gift Certificate Show/Hide\nnavigation\nMy user space My financial space I access my personal space I want to buy a gift certificate\nI was offered an UpCadhoc card I access my management space To place or track your UpCadhoc card orders To track your UpCadhoc card orders I access my management space To place or track your UpCadhoc card orders To track your UpCadhoc card orders My user space\nMy Financial Space My User Space I Access My Personal Space I Want to Buy Gift Certificate I Was Offered an UpCadhoc Card My Financial Space I Access My Management Space To Order or Track Your UpCadhoc Cheques To Track Your UpCadhoc Card Orders Find Us on Search on Cadhoc I Want to Access My Management and Order Space Cadhoc Connect You to Your Customer Space Cadhoc Paper Version Connect You to Your e\nThe ideal solution for motivating, rewarding teams and retaining customers\nA Cooperative and Solidarity Group New!\nDiscover «\nMy Good Plans » Your new benefits platform, 100% for you UpCadhoc:\nThe multi-brand gift voucher solution that makes all the shots happy The first multi-brand gift voucher in France, UpCadhoc allows more than 10 million employees and private individuals to benefit from an extra purchasing power to make themselves happy on a daily basis.\nAvailable as a gift certificate, card or credit card online\n, UpCadhoc offers you privileged access to the largest national shops and the best local shops throughout France!\nUpCadhoc combines the useful with the pleasant so that everyone can use their good gifts according to their desires or needs.\nUseful gift, pleasure gift or gift to share\n, the gift voucher UpCadhoc offers you access to all the gift worlds: fashion, beauty, jewellery, sport, leisure, wellness, home equipment...\nUpCadhoc is a simple, modern, practical gift voucher open to all consumer worlds.\nBenefiting from favourable legislation on social and fiscal charges, the gift title UpCadhoc represents real savings and works in a concrete way to improve the purchasing power of its beneficiaries.\nUpCadhoc, I enjoy it everywhere!\nThe first gift voucher marketed by the Up Group in 1991, the UpCadhoc gift vouchers contribute to a lasting improvement in the living conditions of employees in 14 countries.\nFestive Rendezvous, Family Event, Social Policy, Loyalty Program, Business Gift\n… UpCadhoc brings in a single gift title all the solutions to satisfy your needs\n.\nA product of the Up group Solidarity, freedom, equality and proximity are all notions that UpCadhoc conveys within the Up group.\nThanks to its expertise, UpCadhoc contributes, alongside the other products of the group, to the sustainable improvement of the working and living conditions of employees in their everyday lives.\nWelfare, purchasing power, access to culture, combating precariousness and inequality…\nIn total, more than 27 million people benefit every day from the economic and social solutions of the Up Group.\n\n\n'},
#  {'docno': 'ADD_doc062200210606',
#   'text': '\n\nWhere can I spend my UpCadhoc card and gift vouchers?\nWhere can I spend my cheques and gift cards?\nFind the outlets and locate them on the map.\n1.\nI have:\nA map\nA cheque 2.\nI wish to spend: In shop On internet 3.\nI am looking for a universe:\nBy Ensign By Universe: Beauty & Jewellery Fashion & Accessories Childcare, Games & Culture Leisure & Sport Travel & Relaxation\nHouse & Deco\nGastronomy\nLarge Area & VPC 4.\nWhere?\nAround Me or Street / Town /\nPostal Code\nRecherche Powered by evermaps\n©\nOur Flagship Signs\nOur news\n\n\n'}]

# %%
print('Select overlapping topics...')
topics = pt_dataset.get_topics('text')
topics = topics[topics['qid'].isin(overlapping_queries.keys())]

print(f'Done. Found {len(topics)} overlapping topics.')
# Out:
# Select overlapping topics...
# Done. Found 195 overlapping topics.

# %%
print('docs_for_reformulation:', len(docs_for_reformulation))
print('additional_docs:', len(additional_docs))
# Out:
# docs_for_reformulation: 91458
# additional_docs: 8473

# %%
iter_indexer = pt.IterDictIndexer("/tmp/reformulation-index", meta={'docno': 50, 'text': 4096}, overwrite=True)
index_old = iter_indexer.index(tqdm(docs_for_reformulation + additional_docs, 'Index'))
# Out:
# Index: 100%|██████████| 99931/99931 [01:13<00:00, 1359.47it/s]

# %%
oracle_retrieval = []

for _, topic in topics.iterrows():
    r = 0
    for hit in sorted(oracle_index[__normalize_queries(overlapping_queries[topic['qid']])], key=lambda x: x['relevance'], reverse=True):
        #print(hit)
        r += 1
        oracle_retrieval += [{'qid': topic['qid'], 'query': topic['query'], 'docno': 'ADD_' + hit['doc_id'], 'rank': r, 'score': 100-r, 'run_id': 'oracle'}]

oracle_retrieval = pd.DataFrame(oracle_retrieval)
oracle_retrieval = pt.transformer.get_transformer(oracle_retrieval)

# %%
oracle_retrieval(topics)
# Out:
#                     qid              query                docno  rank  score  \
# 0              q0123836       potato patty  ADD_doc062200201250     1     99
# 1              q0123836       potato patty  ADD_doc062200208494     2     98
# 2              q0123836       potato patty  ADD_doc072205600709     3     97
# 3              q0123836       potato patty  ADD_doc072215803774     4     96
# 4              q0123836       potato patty  ADD_doc062200106362     5     95
# ...                 ...                ...                  ...   ...    ...
# 1739  q0123137438954745  used electric car  ADD_doc092202306639    17     83
# 1740  q0123137438954745  used electric car  ADD_doc092204905125    18     82
# 1741  q0123137438954745  used electric car  ADD_doc092204905125    19     81
# 1742  q0123137438954745  used electric car  ADD_doc092203008286    20     80
# 1743  q0123137438954745  used electric car  ADD_doc092202306639    21     79
#
#       run_id
# 0     oracle
# 1     oracle
# 2     oracle
# 3     oracle
# 4     oracle
# ...      ...
# 1739  oracle
# 1740  oracle
# 1741  oracle
# 1742  oracle
# 1743  oracle
#
# [1744 rows x 6 columns]

# %%
rm3_keyquery_bm25 = oracle_retrieval >> pt.rewrite.RM3(index_old, fb_docs=10, fb_terms=20) >> pt.BatchRetrieve(index, wmodel="BM25")
bo1_keyquery_bm25 = oracle_retrieval >> pt.rewrite.Bo1QueryExpansion(index_old, fb_docs=10, fb_terms=20) >> pt.BatchRetrieve(index, wmodel="BM25")
kl_keyquery_bm25 = oracle_retrieval >> pt.rewrite.KLQueryExpansion(index_old, fb_docs=10, fb_terms=20) >> pt.BatchRetrieve(index, wmodel="BM25")

# %%
pt.Experiment(
    [
        tira.pt.from_submission('ir-benchmarks/tira-ir-starter/BM25 (tira-ir-starter-pyterrier)', dataset_id),
        tira.pt.from_submission('ir-benchmarks/fschlatt/sparse-cross-encoder-4-512', dataset_id),
        tira.pt.from_submission('workshop-on-open-web-search/fschlatt/rank-zephyr', dataset_id),
        rm3_keyquery_bm25,
        bo1_keyquery_bm25,
        kl_keyquery_bm25,
    ],
    topics,
    pt_dataset.get_qrels(),
    ["ndcg", "ndcg_cut.10", "recip_rank", "recall_100"],
    names=["BM25", 'Sparse Cross Encoder', 'RankZephyr', 'RM3 Keyqueries >> BM25', 'BO1 Keyqueries >> BM25', 'KL Keyqueries >> BM25']
)
# Out:
# {'status': 0, 'context': {'include_navigation': False, 'user_id': None, 'role': 'guest', 'organizer_teams': '[]', 'submission': {'docker_software_id': 244, 'display_name': 'BM25 (tira-ir-starter-pyterrier)', 'user_image_name': 'registry.webis.de/code-research/tira/tira-user-tira-ir-starter/pyterrier:0.0.1', 'command': '/workspace/pyterrier_cli.py --input $inputDataset --output $outputDir --index_directory $inputRun --params wmodel=BM25 --retrieval_pipeline default_pipelines.wmodel_batch_retrieve', 'tira_image_name': 'registry.webis.de/code-research/tira/tira-user-tira-ir-starter/pyterrier:0.0.1-tira-docker-software-id-sienna-bug', 'task_id': 'ir-benchmarks', 'vm_id': 'tira-ir-starter', 'description': '', 'paper_link': '', 'input_docker_software': 'Index (tira-ir-starter-pyterrier)', 'input_docker_software_id': 243, 'input_upload_id': None, 'ir_re_ranker': False, 'public_image_name': 'docker.io/webis/ir-benchmarks-submissions:tira-ir-starter-pyterrier-0-0-1-tira-docker-software-id-sienna-bug', 'ir_re_ranking_input': True, 'previous_stages': ['Index (tira-ir-starter-pyterrier)'], 'link_code': None, 'mount_hf_model': None}}}
# {'status': 0, 'context': {'include_navigation': False, 'user_id': None, 'role': 'guest', 'organizer_teams': '[]', 'submission': {'docker_software_id': 2652, 'display_name': 'sparse-cross-encoder-4-512', 'user_image_name': 'registry.webis.de/code-research/tira/tira-user-fschlatt/submission:7a5b6a42c18de612f637157122e1761be82d6f3b', 'command': '/workspace/run-pyterrier-notebook.py --input $inputDataset --output $outputDir --notebook /workspaces/ecir24-sparse-cross-encoder/notebooks/notebook.ipynb', 'tira_image_name': 'registry.webis.de/code-research/tira/tira-user-fschlatt/submission:7a5b6a42c18de612f637157122e1761be82d6f3b-tira-docker-software-id-energetic-ravvet', 'task_id': 'ir-benchmarks', 'vm_id': 'fschlatt', 'description': '', 'paper_link': '', 'input_docker_software': None, 'input_docker_software_id': None, 'input_upload_id': None, 'ir_re_ranker': True, 'public_image_name': 'a', 'ir_re_ranking_input': False, 'previous_stages': None, 'link_code': None, 'mount_hf_model': None}}}
# {'status': 0, 'context': {'include_navigation': False, 'user_id': None, 'role': 'guest', 'organizer_teams': '[]', 'submission': {'docker_software_id': 3068, 'display_name': 'rank-zephyr', 'user_image_name': 'registry.webis.de/code-research/tira/tira-user-fschlatt/fschlatt/r:0.0.1', 'command': 'python3 /workspace/rank_llm/scripts/run_rank_llm.py --model_path=castorini/rank_zephyr_7b_v1_full --top_k_candidates=100 --dataset=$inputDataset/rerank.jsonl.gz --prompt_mode=rank_GPT --context_size=4096 --variable_passages --retrieval_method=unspecified --output_dir=$outputDir', 'tira_image_name': 'registry.webis.de/code-research/tira/tira-user-fschlatt/fschlatt/r:0.0.1-tira-docker-software-id-all-interval', 'task_id': 'workshop-on-open-web-search', 'vm_id': 'fschlatt', 'description': 'An open source clone of RankGPT. The code is a fork of rank_llm using rank-zephyr https://github.com/fschlatt/rank_llm.', 'paper_link': '', 'input_docker_software': None, 'input_docker_software_id': None, 'input_upload_id': None, 'ir_re_ranker': True, 'public_image_name': 'docker.io/webis/workshop-on-open-web-search-submissions:fschlatt-fschlatt-r-0-0-1-tira-docker-software-id-all-interval', 'ir_re_ranking_input': False, 'previous_stages': None, 'link_code': None, 'mount_hf_model': 'castorini/rank_zephyr_7b_v1_full'}}}
#                      name      ndcg  ndcg_cut.10  recip_rank  recall_100
# 0                    BM25  0.350489     0.171283    0.336867    0.547271
# 1    Sparse Cross Encoder  0.327323     0.202812    0.376275    0.547271
# 2              RankZephyr  0.342603     0.223018    0.435556    0.547271
# 3  RM3 Keyqueries >> BM25  0.422255     0.229326    0.461395    0.641683
# 4  BO1 Keyqueries >> BM25  0.443201     0.244972    0.505799    0.670757
# 5   KL Keyqueries >> BM25  0.440022     0.243748    0.492165    0.673453

# %%
rm3_keyquery_bm25(topics)
# Out:
#                       qid    docid            docno  rank      score  \
# 0       q0123103079215846  1340293  doc012311802304     0  28.662406
# 1       q0123103079215846  1120561  doc012301310377     1  28.521230
# 2       q0123103079215846  1586428  doc012312006255     2  28.507358
# 3       q0123103079215846   766422  doc012302813370     3  28.376519
# 4       q0123103079215846  1586721  doc012312006548     4  28.248832
# ...                   ...      ...              ...   ...        ...
# 194995   q012394489282336   609542  doc012304101836   995  17.658995
# 194996   q012394489282336  1423406  doc012311208667   996  17.655327
# 194997   q012394489282336    94503  doc012308213952   997  17.648631
# 194998   q012394489282336  1981915  doc012310507758   998  17.647480
# 194999   q012394489282336   239307  doc012305113588   999  17.643057
#
#                query_0                                              query
# 0       schengen space  applypipeline:off space^0.300000012 resid^0.02...
# 1       schengen space  applypipeline:off space^0.300000012 resid^0.02...
# 2       schengen space  applypipeline:off space^0.300000012 resid^0.02...
# 3       schengen space  applypipeline:off space^0.300000012 resid^0.02...
# 4       schengen space  applypipeline:off space^0.300000012 resid^0.02...
# ...                ...                                                ...
# 194995       leek soup  applypipeline:off music^0.014745858 cookbook^0...
# 194996       leek soup  applypipeline:off music^0.014745858 cookbook^0...
# 194997       leek soup  applypipeline:off music^0.014745858 cookbook^0...
# 194998       leek soup  applypipeline:off music^0.014745858 cookbook^0...
# 194999       leek soup  applypipeline:off music^0.014745858 cookbook^0...
#
# [195000 rows x 7 columns]

# %%
bm25_foo = pt.BatchRetrieve(index, wmodel='BM25')

# %%
bm25_foo.search('sda')
# Out:
#    qid  docid                docno  rank      score query
# 0    1  29000      doc012306005842     0  22.900290   sda
# 1    1  23856      doc012305705148     1  22.513659   sda
# 2    1  87899      doc012300603031     2  21.086208   sda
# 3    1  61811      doc012307305274     3  16.749233   sda
# 4    1  63928      doc012310906127     4  15.593594   sda
# 5    1  74584      doc012303907912     5  15.575961   sda
# 6    1  41945      doc012311711774     6  14.950474   sda
# 7    1  14079      doc012305800975     7  14.805850   sda
# 8    1  40311      doc012304511683     8  14.648405   sda
# 9    1  20946      doc012304406557     9  14.433524   sda
# 10   1   8222      doc012302109220    10  13.486718   sda
# 11   1  95535  ADD_doc062200100279    11  13.329676   sda
# 12   1  94216  ADD_doc072202308234    12  13.271883   sda
# 13   1  95882  ADD_doc062200205166    13  13.271883   sda
# 14   1  25102      doc012306801805    14  13.076599   sda
# 15   1  65718      doc012309510706    15  12.262157   sda
# 16   1  88255      doc012300609049    16  12.229498   sda
# 17   1   9840      doc012304209740    17  11.214005   sda
# 18   1  35873      doc012311108409    18  11.159497   sda
# 19   1  32329      doc012311608638    19  10.834730   sda
# 20   1  43797      doc012312700010    20  10.792287   sda
# 21   1  48826      doc012308405485    21  10.666654   sda
# 22   1  10246      doc012303800779    22   9.451932   sda
# 23   1  10949      doc012305103395    23   9.426061   sda
# 24   1  73634      doc012309601152    24   9.267520   sda
# 25   1  63329      doc012311208171    25   9.006954   sda
# 26   1   8673      doc012302116826    26   8.936833   sda
# 27   1  18838      doc012302200035    27   8.896431   sda
# 28   1  27295      doc012300318842    28   8.873507   sda
# 29   1  72565      doc012300500140    29   8.732870   sda
# 30   1  28900      doc012306003253    30   8.716293   sda
# 31   1  91540  ADD_doc092201605889    31   8.516894   sda
# 32   1  47719      doc012309314018    32   8.202464   sda
# 33   1  82732      doc012310310391    33   7.203094   sda
# 34   1  33069      doc012302007516    34   6.536577   sda
